# %%
import pandas as pd
from seminar_2_major_assignment.config import PROCESSED_DATA_DIR

# Load processed data
df = pd.read_csv(PROCESSED_DATA_DIR / "dataset.csv")

# Basic analysis
df.head()
# Out:
# 2026-01-29 13:12:48.258 | INFO     | seminar_2_major_assignment.config:<module>:11 - PROJ_ROOT path is: /Users/ebader2/ds-projects/seminar_2_major_assignment
#           name    year  arealand_sqmi  education_b15003_001e  \
# 0      Allston  2025.0       1.377620                18341.0
# 1     Back Bay  2025.0       0.511202                14235.0
# 2  Beacon Hill  2025.0       0.277307                 7537.0
# 3     Brighton  2025.0       2.713007                39238.0
# 4  Charlestown  2025.0       1.353655                14997.0
#
#    education_b15003_lt9th  education_b15003_9th_to_12thnodiploma  \
# 0              334.843644                             193.926605
# 1              118.099429                              50.905669
# 2              112.768853                              19.550000
# 3             1345.894929                            1189.355076
# 4              309.443348                             565.762779
#
# ...

# %%
df["education_b15003_lt9th"].mean()
# Out:
# np.float64(1349.214888648261)

# %%
df.describe()
# Out:
#          year  arealand_sqmi  education_b15003_001e  education_b15003_lt9th  \
# count    23.0      23.000000              23.000000               23.000000
# mean   2025.0       2.053131           21405.913043             1349.214889
# std       0.0       1.970364           17363.886083             1915.787974
# min    2025.0       0.110478             560.000000               11.495455
# 25%    2025.0       0.556365            8885.000000              223.100684
# 50%    2025.0       1.353655           17687.000000              638.716700
# 75%    2025.0       3.057795           30144.000000             1489.255559
# max    2025.0       7.277603           83140.000000             8250.956696
#
#        education_b15003_9th_to_12thnodiploma  education_b15003_hsgrad_and_ged  \
# count                              23.000000                        23.000000
# mean                              962.044307                      3781.014729
# ...
